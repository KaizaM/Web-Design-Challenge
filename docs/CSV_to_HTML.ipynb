# %%
import pandas as pd

# %%
#read in csv
data = pd.read_csv("../Resources/cities.csv")

# %%
#html code
print(data.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Long</th>
#       <th>Max Temp (F)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bredasdorp</td>
#       <td>ZA</td>
#       <td>-34.5322</td>
#       <td>20.0403</td>
#       <td>61.41</td>
#       <td>52</td>
#       <td>81</td>
#       <td>8.75</td>
#       <td>1650652147</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Nikolskoye</td>
#       <td>RU</td>
#       <td>59.7035</td>
#       <td>30.7861</td>
#       <td>51.69</td>
#       <td>72</td>
#       <td>100</td>
#       <td>3.96</td>
#       <td>1650652147</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arraial do Cabo</td>
#       <td>BR</td>
#       <td>-22.9661</td>
# ...

# %%
#save as html
data.to_html('csv_data.html', index = False)
